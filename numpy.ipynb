# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1 - Leia o dataset usando pandas.

# %%
archive = pd.read_csv("Salary_Data.csv")

# %% [markdown]
# 2 - Converta os dados relevantes em arrays NumPy (utilize o método .to_numpy())

# %%
salarydata = archive.to_numpy()

# %% [markdown]
# 3 - Calcule a média de salários.

# %%
column1 = salarydata[1:, 1].astype(float)
media = np.mean(column1)
print(f"Média salarial: R$ {media:.2f}")
# Out:
# Média salarial: R$ 77267.14

# %% [markdown]
# 4 - Calcule a média de tempo de serviço.

# %%
column0 = salarydata[1:, 0].astype(float)
media = np.mean(column0)
print(f"Média de tempo de serviço: {media:.2f}")
# Out:
# Média de tempo de serviço: 5.46

# %% [markdown]
# 5 - Encontre o salário médio dos funcionários com mais de 5 anos de serviço.

# %%
employees = column1[column0 > 5]
average_salary = np.mean(employees)
print(f"Média salarial de funcionários com mais de 5 anos de serviço: R$ {average_salary:.2f}")
# Out:
# Média salarial de funcionários com mais de 5 anos de serviço: R$ 101316.07

# %% [markdown]
# 6 - Crie um gráfico de barras mostrando os salários referente ao tempo de serviço.

# %%
plt.bar(archive['YearsExperience'], archive['Salary'])
plt.title("Projeção do salário em relação ao tempo de serviço")
plt.xlabel("Anos de Serviço")
plt.ylabel("Salário")
plt.show()

# %% [markdown]
# 7 - Considere um aumento de 10% para o salário de cada funcionário e apresente o resultado do aumento.

# %%
archive['Salary'] = archive['Salary'] * 1.1
salarydata = archive.to_numpy()
column1 = salarydata[1:, 1].astype(float)
media = np.mean(column1)
print(f"Nova média salarial: R$ {media:.2f}")
'''
Printar o gráfico, caso queira:

plt.bar(archive['YearsExperience'], archive['Salary'])
plt.title("Projeção do salário em relação ao tempo de serviço")
plt.xlabel("Anos de Serviço")
plt.ylabel("Salário")
plt.show()
'''
# Out:
# Nova média salarial: R$ 84993.85
# '\nPrintar o gráfico, caso queira:\n\nplt.bar(archive[\'YearsExperience\'], archive[\'Salary\'])\nplt.title("Projeção do salário em relação ao tempo de serviço")\nplt.xlabel("Anos de Serviço")\nplt.ylabel("Salário")\nplt.show()\n'
